# %% [markdown]
# ## Load Environvent

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ABHISHEK\maven\.venv\Scripts\python.exe

# %%
uv run pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.1
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.21
# decorator               5.3.1
# distlib                 0.3.6
# executing               2.2.1
# filelock                3.12.0
# ipykernel               7.3.0
# ipython                 9.15.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.20.0
# jupyter_client          8.9.1
# jupyter_core            5.9.1
# matplotlib-inline       0.2.2
# nest-asyncio2           1.7.2
# packaging               26.2
# parso                   0.8.7
# pip                     25.3
# platformdirs            3.5.0
# prompt_toolkit          3.0.52
# psutil                  7.2.2
# pure_eval               0.2.3
# Pygments                2.20.0
# python-dateutil         2.9.0.post0
# pyzmq                   27.1.0
# setuptools              80.9.0
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.7
# traitlets               5.15.1
# typing_extensions       4.16.0
# uv                      0.9.24
# virtualenv              20.23.0
# wcwidth                 0.8.2
# wheel                   0.45.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Google GenAi client

# %%
from google import genai

gemini_client=genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain Retrieval-Augmented Generation (RAG) in simple terms."
)

print(response.text)
# Out:
# Imagine you are taking a history exam.
#
# * **Without RAG (Closed-Book Exam):** You have to answer all the questions relying *only* on what you can remember. If you forget a detail, you might guess or make something up that sounds plausible. This is how standard AI (like ChatGPT) works normally.
# * **With RAG (Open-Book Exam):** Before you answer, the teacher hands you a stack of textbooks and says, "You can look up the facts in these books before you write your answer." This is **Retrieval-Augmented Generation (RAG)**.
#
# In short, **RAG is a way of giving an AI model an "open-book" to look up accurate, up-to-date information before it answers your question.**
#
# ---
#
# ### Why do we need RAG?
# Standard AI models are very smart, but they have two big limitations:
# 1. **They have a cutoff date:** They only know what happened up until they were trained (e.g., they might not know who won yesterday’s game).
# 2. **They don't know your private data:** They don't know about your company’s internal PDFs, your personal emails, or today's news.
# 3. **They "hallucinate":** When they don't know the answer, they sometimes confidently make up false information.
#
# RAG fixes all of these problems.
#
# ---
#
# ### How RAG Works in 3 Simple Steps
#
# When you ask a RAG-enabled AI a question (like, *"What is our company's policy on work-from-home?"*), it does the following:
#
# 1. **Retrieve (Find the Facts):** The AI searches a specific database or folder of documents (your company’s HR handbook, in this case) to find the exact pages that mention "work-from-home."
# 2. **Augment (Add the Facts to the Prompt):** The AI takes your original question and glues the relevant pages it found onto it.
# 3. **Generate (Write the Answer):** The AI reads the pages it was just handed and writes a neat, accurate summary for you.
#
# ---
#
# ### Why is this a game-changer?
#
# * **No more "hallucinations":** Because the AI must base its answer on the provided documents, it is much less likely to make things up.
# * **Always up-to-date:** You don't need to spend millions of dollars retraining the AI every time something changes. You just update the document folder, and the AI immediately has access to the new information.
# * **Data Privacy:** You can connect the AI to your private personal or company documents without sharing them with the public internet.

# %% [markdown]
# ## GROQ CLIENT

# %%
from groq import Groq

# %%
load_dotenv()

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY")
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain RAG in simple terms."
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# RAG (Retrieval, Augmentation, Generation) is an AI concept that helps generate more accurate and informative responses. Here's a simplified breakdown:
#
# 1. **Retrieval**: The AI searches for relevant information from a large database or knowledge base to find answers to a given question or prompt.
# 2. **Augmentation**: The AI takes the retrieved information and adds more context, details, or relevant data to it. This helps to make the response more comprehensive and accurate.
# 3. **Generation**: The AI uses the augmented information to generate a final response. This response is often written in a natural, human-like tone and is tailored to the specific question or prompt.
#
# Think of RAG like a researcher who:
#
# * Retrieves information from books and articles (Retrieval)
# * Adds more details and context to the information (Augmentation)
# * Writes a well-informed and engaging report based on the information (Generation)
#
# By following these steps, RAG helps AI models provide more accurate, informative, and helpful responses to users.
